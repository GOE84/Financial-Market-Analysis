# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
import mplfinance as mpf
import pandas as pd

# %%
TICKER = 'CPALL.BK'  
START_DATE = '2024-01-01'
END_DATE = '2025-01-01'
RAW_DATA_PATH = '../data/raw/stock_price.csv' # เซฟย้อนกลับไปที่โฟลเดอร์ data/raw

# %%
print(f"this TICKER is {TICKER}...")
data = yf.download(TICKER, start=START_DATE, end=END_DATE)
# Out:
# /tmp/ipython-input-4156853533.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(TICKER, start=START_DATE, end=END_DATE)
# [*********************100%***********************]  1 of 1 completed
# this TICKER is CPALL.BK...

# %%
print("\nตัวอย่างข้อมูล:AAPL")
print(data.head())
# Out:
# ตัวอย่างข้อมูล:AAPL
# Price           Close       High        Low       Open    Volume
# Ticker       CPALL.BK   CPALL.BK   CPALL.BK   CPALL.BK  CPALL.BK
# Date
# 2024-01-03  53.349594  54.306538  53.110358  54.306538  17781400
# 2024-01-04  53.588833  53.828069  52.631889  53.110361  21277000
# 2024-01-05  53.110359  53.828067  52.631887  53.349595  36798200
# 2024-01-08  52.871124  53.110360  52.153417  52.871124  21102800
# 2024-01-09  52.153416  53.349595  51.914180  53.110359  16519400

# %%
print(data.isnull().sum())
# Out:
# Price   Ticker
# Close   CPALL.BK    0
# High    CPALL.BK    0
# Low     CPALL.BK    0
# Open    CPALL.BK    0
# Volume  CPALL.BK    0
# dtype: int64

# %%
os.makedirs(os.path.dirname(RAW_DATA_PATH), exist_ok=True)
data.to_csv(RAW_DATA_PATH)
print(f"\nData saved to {RAW_DATA_PATH}")
# Out:
# Data saved to ../data/raw/stock_price.csv

# %%
if isinstance(data.columns, pd.MultiIndex):
    data.columns = data.columns.get_level_values(1)

# %%
# 5. พล็อตกราฟราคาปิดดูทรง
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Close Price', color='blue')
plt.title(f'{TICKER} Stock Price ({START_DATE} - {END_DATE})')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.grid(True)
plt.show()

# %%
if len(data) == 0:
    print("No data fetched. Please check the TICKER symbol and date range.")
else:
    print("กำลังสร้างกราฟราคาปิด...")
    mpf.plot(
        data,
        type='candle',
        mav=(12,20),
        volume=True,
        title = f'Stock Price : {TICKER}',
        style='yahoo'
    )
# Out:
# กำลังสร้างกราฟราคาปิด...
